# %%
from mypackage import arith

# %%
arith.add_numbers(2, 3)
# Out:
# 5

# %%
import mypackage.arith

print(dir(mypackage.arith))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'add_numbers', 'division', 'multiple', 'power', 'remainder', 'subtract']

# %%
help(mypackage.arith)
# Out:
# Help on module mypackage.arith in mypackage:
#
# NAME
#     mypackage.arith
#
# DESCRIPTION
#     # mypackage/arithmetics.py
#     # arithmetics.py
#
# FUNCTIONS
#     add_numbers(*args)
#         # mypackage/arithmetics.py
#         # arithmetics.py
#
#     division(a, b)
#
#     multiple(a, b)
#
#     power(a, b)
#
#     remainder(a, b)
#
#     subtract(a, b)
#
# FILE
#     c:\users\sic\desktop\projects\sic-nlp\mypackage\arith.py
